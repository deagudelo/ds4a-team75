# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import os

# %%
pd.set_option('display.max_columns', 50)

# %%
os.listdir('Created_Data')
# Out:
# ['AISLADE_clean.csv',
#  'CallOT_failures_URABA.csv',
#  'CON_PRI_clean.csv',
#  'CUCHILL_clean.csv',
#  'OTdetails_failures_URABA.csv',
#  'RECONEC_clean.csv',
#  'TRANSFO_clean.csv']

# %%
failures = pd.read_csv('Created_Data/CallOT_failures_URABA.csv')
aislade = pd.read_csv('Created_Data/AISLADE_clean.csv')
con_pri = pd.read_csv('Created_Data/CON_PRI_clean.csv')
cuchill = pd.read_csv('Created_Data/CUCHILL_clean.csv')
reconec = pd.read_csv('Created_Data/RECONEC_clean.csv')
transfo = pd.read_csv('Created_Data/TRANSFO_clean.csv')

# %%
failures.head()
# Out:
#           CallOtID                  CallID  NumberOT     Status  \
# 0  3974557-3294596        M_EPM_EN_3974557   3294596  Realizada
# 1  3974642-3294347        M_EPM_EN_3974642   3294347  Realizada
# 2  3974707-3294568        M_EPM_EN_3974707   3294568  Realizada
# 3  2037523-2037523  MX_EPM_0133_DE_2037523   2037523  Realizada
# 4  3974852-3294520        M_EPM_EN_3974852   3294520  Realizada
#
#                          ServiceType                  Eng_Type  DuratioMin  \
# 0                      Daños Energía  CU-TyD-Moto_MttoDaños_X1          30
# 1                      Daños Energía  CU-TyD-Moto_MttoDaños_X1          30
# 2                      Daños Energía  CU-TyD-Moto_MttoDaños_X1          30
# 3  Mto. Ener. Actividades Forestales       CU-TyD-Moto_Poda_X2         600
# 4                      Daños Energía  CU-TyD-Moto_MttoDaños_X1          30
#
#          TaskType      District       BusinessLine           Municipio  \
# 0  TRABAJOFUSIBLE  Apartado TyD          Daños TyD              CAREPA
# 1       INSPECQOS     Turbo TyD          Daños TyD               TURBO
# 2       INSPECQOS     Turbo TyD          Daños TyD             NECOCLÍ
# 3       PODARED01     Turbo TyD  Mantenimiento TyD             NECOCLÍ
# 4  TRABAJOFUSIBLE     Turbo TyD          Daños TyD  SAN PEDRO DE URABÁ
#
#    Latitude  Longitude  Priority IncompleteReason       LocationID Circuit  \
# 0  7.771097 -76.809294         1        NO APLICA           FR4159  405-13
# 1  8.108337 -76.732551         4        NO APLICA  NO ESPECIFICADO  402-11
# 2  8.466042 -76.598210         4        NO APLICA           489023  415-12
# 3  8.420147 -76.646490         7        NO APLICA            R1269  415-12
# 4  8.418435 -76.304074         1        NO APLICA           478088  407-12
#
#     LocationResume
# 0        AISLADERO
# 1  SALIDA CIRCUITO
# 2    TRANSFORMADOR
# 3         SEGMENTO
# 4    TRANSFORMADOR

# %%
transfo.TRANSF_CODE = transformadores.TRANSF_CODE.astype(str)
transfo.head()
# Out:
#    G3E_FID LOCALIZACI     SUBESTACIO CIRCUITO  TIPO_RED  TENSION  CAPACIDAD_  \
# 0  7001338      AEREO  S.PEDRO URABA   407-12  PRIMARIA    7.621        15.0
# 1  7001669      AEREO          TURBO   402-13  PRIMARIA    7.621        10.0
# 2  7001671      AEREO          TURBO   402-13  PRIMARIA    7.621        25.0
# 3  7001672      AEREO          TURBO   402-13  PRIMARIA    7.621        25.0
# 4  7001675      AEREO          TURBO   402-13  PRIMARIA    7.621        37.5
#
#   FASES TRANSF_CODE  NODO_TRANS  ...  NODO1_ID  NODO2_ID  NODO_TRAN1  \
# 0     S      477213      477213  ...  47674497  57745411      477213
# 1     T      418251      418251  ...  57403494  57680127      418251
# 2     S       70632      418240  ...  57680296  57282032      418240
# 3     T      418241      418241  ...  53148542         0      418241
# 4     R      405083      405083  ...  57719671  57719670      405083
#
#       SUBESTACI1 CIRCUITO_C TENSION_CO  FASES_CONN  NUMERO_FAS  \
# 0  S.PEDRO URABA     407-12      7.621           S          1F
# 1          TURBO     402-13      7.621           T          1F
# 2          TURBO     402-13      7.621           S          1F
# 3          TURBO     402-13      7.621           T          1F
# 4          TURBO     402-13      7.621           R          1F
#
#    MUNICIPIO_CODE SUBREGION
# 0            5665     TURBO
# 1            5837     TURBO
# 2            5837     TURBO
# 3            5837     TURBO
# 4            5837     TURBO
#
# [5 rows x 26 columns]

# %%
p1 = failures.merge(transfo, left_on='LocationID', right_on='TRANSF_CODE', how='inner')

# %%
p1.shape
# Out:
# (8219, 44)

# %%
failures.LocationResume.value_counts()
# Out:
# TRANSFORMADOR            26894
# SALIDA CIRCUITO           5663
# SEGMENTO                  1515
# AISLADERO                 1338
# TRAMO                     1257
# NO ESPECIFICADO           1044
# RECONECTADOR               362
# ALIMENTADOR PRINCIPAL      256
# NODO                       227
# RAMAL                       33
# Name: LocationResume, dtype: int64

# %%
pp2= aislade.append(con_pri).append(cuchill).append(reconec).append(transfo)
pp2.fillna('NO APLICA', inplace=True)

# %%
pp2.head()
# Out:
#    G3E_FID  MUNICIPIO SUBESTACIO CIRCUITO CIRCUITO_S EST_ESTABL TIPO_AISLA  \
# 0  4115654      TURBO  CHIGORODO   403-16     403-16     CLOSED     NORMAL
# 1  4115657  CHIGORODÓ  CHIGORODO   403-16     403-16     CLOSED     NORMAL
# 2  4115659  CHIGORODÓ  CHIGORODO   403-16     403-16     CLOSED     NORMAL
# 3  4115660  CHIGORODÓ  CAUCHERAS   404-12     404-12     CLOSED     NORMAL
# 4  4115661  CHIGORODÓ  CAUCHERAS   404-12     404-12     CLOSED     NORMAL
#
#    TIPO_RED  TENSION FASES LATITUDE LONGITUDE  FECHA_COLO  FECHA_MODI  \
# 0  PRIMARIA    7.621     T  7.47868  -76.6921  2007-12-06  2019-10-18
# 1  PRIMARIA    7.621     R  7.57476  -76.6259  2007-12-06  2020-04-24
# 2  PRIMARIA    7.621     S  7.55712  -76.6151  2007-12-06  2020-04-24
# 3  PRIMARIA    7.621     R  7.52118  -76.5979  2007-12-06  2018-07-07
# 4  PRIMARIA    7.621     R  7.51845   -76.595  2007-12-06  2018-07-07
#
#   CLASIFICAC  NODO1_ID  NODO2_ID NUMERO_FAS MUNICIPIO_CODE SUBREGION  \
# 0      RURAL  51148589  51148590         1F           5837  APARTADO
# 1      RURAL  47636661  51148627         1F           5172  APARTADO
# 2      RURAL  57368114  57742128         1F           5172  APARTADO
# 3      RURAL  47639963  51148644         1F           5172  APARTADO
# 4      RURAL  51148646  51148647         1F           5172  APARTADO
#
#   LOCALIZACI    CALIBRE   MATERIAL AISLAMIENT        USO SOBREPUEST  \
# 0  NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA
# 1  NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA
# 2  NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA
# 3  NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA
# 4  NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA
#
#   TIPO_LINEA LONGITUD_C CUCHILL_CODE SUBESTACI1 RECONEC_CODE CAPACIDAD_  \
# 0  NO APLICA  NO APLICA    NO APLICA  NO APLICA    NO APLICA  NO APLICA
# 1  NO APLICA  NO APLICA    NO APLICA  NO APLICA    NO APLICA  NO APLICA
# 2  NO APLICA  NO APLICA    NO APLICA  NO APLICA    NO APLICA  NO APLICA
# 3  NO APLICA  NO APLICA    NO APLICA  NO APLICA    NO APLICA  NO APLICA
# 4  NO APLICA  NO APLICA    NO APLICA  NO APLICA    NO APLICA  NO APLICA
#
#   TRANSF_CODE NODO_TRANS NODO_TRAN1 CIRCUITO_C TENSION_CO FASES_CONN
# 0   NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA
# 1   NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA
# 2   NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA
# 3   NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA
# 4   NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA  NO APLICA
